# %%
from ParsingText import ParsingText

# %%
# %%time
res = []
for _ in range(10000):
    test = "请帮我打开电视"
    if u"电视" in test:
        res.append(True)
# Out:
# Wall time: 2.99 ms

# %%
# %%time
res = []
for _ in range(10000):
    test = "请帮我打开电视"
    pt = ParsingText(test)
    nouns = pt.get_noun()
    if u"电视" in nouns:
        res.append(True)
# Out:
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# 请	帮	我	打开	电视
# 词性标注:
# v	v	r	v	n
# 命名实体识别:
# O	O	O	O	O
# 分词:
# ...
