# %%
import redis

# %%
help(redis)
# Out:
# Help on package redis:
#
# NAME
#     redis
#
# PACKAGE CONTENTS
#     _compat
#     client
#     connection
#     exceptions
#     lock
#     sentinel
#     utils
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         redis.exceptions.RedisError
#             redis.exceptions.AuthenticationError
#             redis.exceptions.ConnectionError
#                 redis.exceptions.BusyLoadingError
#             redis.exceptions.DataError
#             redis.exceptions.InvalidResponse
#             redis.exceptions.PubSubError
#             redis.exceptions.ResponseError
#                 redis.exceptions.ReadOnlyError
#             redis.exceptions.TimeoutError
#             redis.exceptions.WatchError
#     builtins.object
#         redis.client.StrictRedis
#             redis.client.Redis
#         redis.connection.Connection
#             redis.connection.SSLConnection
#             redis.connection.UnixDomainSocketConnection
#         redis.connection.ConnectionPool
# ...

# %%
help(redis.client)
# Out:
# Help on module redis.client in redis:
#
# NAME
#     redis.client
#
# CLASSES
#     builtins.object
#         BasePipeline
#             Pipeline(BasePipeline, Redis)
#             StrictPipeline(BasePipeline, StrictRedis)
#         PubSub
#         Script
#         StrictRedis
#             Redis
#     threading.Thread(builtins.object)
#         PubSubWorkerThread
#
#     class BasePipeline(builtins.object)
#      |  Pipelines provide a way to transmit multiple commands to the Redis server
#      |  in one transmission.  This is convenient for batch processing, such as
#      |  saving all the values in a list to Redis.
#      |
#      |  All commands executed within a pipeline are wrapped with MULTI and EXEC
#      |  calls. This guarantees all commands executed in the pipeline will be
#      |  executed atomically.
#      |
#      |  Any command raising an exception does *not* halt the execution of
#      |  subsequent commands in the pipeline. Instead, the exception is caught
# ...

# %%
client = redis.Redis(host='127.0.0.1')

# %%
client.keys()
# Out:
# [b'_kombu.binding.celeryev', b'name', b'_kombu.binding.celery', b'date']

# %%
client.get('name')
# Out:
# b'chris180523'

# %%
import pickle
with open('test.pdf','rb') as f:
    content = f.read()
    print(len(content))
# Out:
# 352575

# %%
client.set('pdf',content)
# Out:
# True

# %%
client.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-099dbd688d81> in <module>()
# ----> 1 client.exit()
#
# AttributeError: 'Redis' object has no attribute 'exit'

# %%
client.get('pdf')
